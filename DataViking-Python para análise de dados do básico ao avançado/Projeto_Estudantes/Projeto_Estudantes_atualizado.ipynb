# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# Lendo a Base de Dados
Base_Dados = pd.read_csv('/home/wermelinger_v/Documentos/GitHub/DataViking/DataViking-Python para análise de dados do básico ao avançado/Projeto_Estudantes/StudentsPerformance.csv')

# dimensão
Base_Dados.shape
# Out:
# (1000, 8)

# %%
# Head
Base_Dados.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Campus nulos 
Nulos = Base_Dados.isnull()
plt.figure(figsize=(16,5))
plt.title('Analise campos nulos')
sns.heatmap(Nulos, cbar=False)
# Out:
# <Axes: title={'center': 'Analise campos nulos'}>

# %%
Nulos.sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Unicos (tipos de categoria)

Base_Dados.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
# Campos duplicados 
Base_Dados.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Estatística 
Base_Dados.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# Informações 
Base_Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
Base_Dados['gender'].value_counts(normalize=True) * 100
# Out:
# gender
# female    51.8
# male      48.2
# Name: proportion, dtype: float64

# %%
Base_Dados['race/ethnicity'].value_counts(normalize=True) * 100
# Out:
# race/ethnicity
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: proportion, dtype: float64

# %%
Base_Dados["parental level of education"].value_counts(normalize=True) * 100
# Out:
# parental level of education
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: proportion, dtype: float64

# %%
Base_Dados['lunch'].value_counts(normalize=True) * 100
# Out:
# lunch
# standard        64.5
# free/reduced    35.5
# Name: proportion, dtype: float64

# %%
Base_Dados['test preparation course'].value_counts(normalize=True) * 100
# Out:
# test preparation course
# none         64.2
# completed    35.8
# Name: proportion, dtype: float64

# %%
sns.boxplot(Base_Dados, x="math score" , y= "gender")
# Out:
# <Axes: xlabel='math score', ylabel='gender'>

# %%
sns.boxplot(Base_Dados, x="reading score" , y= "gender")
# Out:
# <Axes: xlabel='reading score', ylabel='gender'>

# %%
sns.boxplot(Base_Dados, x="writing score" , y= "gender")
# Out:
# <Axes: xlabel='writing score', ylabel='gender'>

# %%
Base_Dados.groupby(by=['gender']).describe()
# Out:
#        math score                                                       \
#             count       mean        std   min   25%   50%   75%    max
# gender
# female      518.0  63.633205  15.491453   0.0  54.0  65.0  74.0  100.0
# male        482.0  68.728216  14.356277  27.0  59.0  69.0  79.0  100.0
#
#        reading score             ...              writing score             \
#                count       mean  ...   75%    max         count       mean
# gender                           ...
# female         518.0  72.608108  ...  83.0  100.0         518.0  72.467181
# male           482.0  65.473029  ...  75.0  100.0         482.0  63.311203
#
#
#               std   min   25%   50%    75%    max
# gender
# female  14.844842  10.0  64.0  74.0  82.00  100.0
# male    14.113832  15.0  53.0  64.0  73.75  100.0
#
# [2 rows x 24 columns]

# %%
Base_Dados.groupby(by=['gender']).describe()['math score'].reset_index()
# Out:
#    gender  count       mean        std   min   25%   50%   75%    max
# 0  female  518.0  63.633205  15.491453   0.0  54.0  65.0  74.0  100.0
# 1    male  482.0  68.728216  14.356277  27.0  59.0  69.0  79.0  100.0

# %%
Base_Dados.groupby(by=['gender']).describe()['reading score'].reset_index()
# Out:
#    gender  count       mean        std   min    25%   50%   75%    max
# 0  female  518.0  72.608108  14.378245  17.0  63.25  73.0  83.0  100.0
# 1    male  482.0  65.473029  13.931832  23.0  56.00  66.0  75.0  100.0

# %%
Base_Dados.groupby(by=['gender']).describe()['writing score'].reset_index()
# Out:
#    gender  count       mean        std   min   25%   50%    75%    max
# 0  female  518.0  72.467181  14.844842  10.0  64.0  74.0  82.00  100.0
# 1    male  482.0  63.311203  14.113832  15.0  53.0  64.0  73.75  100.0

# %%
sns.pairplot(Base_Dados)

# %%
sns.pairplot(Base_Dados, hue='race/ethnicity')

# %%
sns.boxplot(data=Base_Dados,x='math score', y="race/ethnicity")
# Out:
# <Axes: xlabel='math score', ylabel='race/ethnicity'>

# %%
sns.boxplot(data=Base_Dados,x='reading score', y="race/ethnicity")
# Out:
# <Axes: xlabel='reading score', ylabel='race/ethnicity'>

# %%
sns.boxplot(data=Base_Dados,x='writing score', y="race/ethnicity")
# Out:
# <Axes: xlabel='writing score', ylabel='race/ethnicity'>

# %%
sns.boxplot(data=Base_Dados,x='math score', y="parental level of education")
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %%
sns.boxplot(data=Base_Dados,x='reading score', y="parental level of education")
# Out:
# <Axes: xlabel='reading score', ylabel='parental level of education'>

# %%
sns.boxplot(data=Base_Dados,x='writing score', y="parental level of education")
# Out:
# <Axes: xlabel='writing score', ylabel='parental level of education'>
